# %% [markdown]
# # Stock Price Prediction (LSTM + ARIMA) — one-click run
# Runs the hybrid LSTM + ARIMA forecaster on live Yahoo Finance data and prints MSE / R² plus prediction plots.
# Just press **Runtime → Run all** (or run each cell top to bottom).

# %%
# !git clone https://github.com/akshay-birla-03/stock-price-prediction-model.git
# %cd stock-price-prediction-model

# %%
# !pip install -q yfinance numpy pandas matplotlib scikit-learn tensorflow statsmodels

# %% [markdown]
# ### Run the forecaster
# Edit the `ticker` inside `stock_price_prediction_lstm_arima.py` to try a different symbol (e.g. `RELIANCE.NS`).

# %%
# !python stock_price_prediction_lstm_arima.py
